# %% [markdown]
# # Unity ML Agents
# ## Proximal Policy Optimization (PPO)
# Contains an implementation of PPO as described [here](https://arxiv.org/abs/1707.06347).

# %%
import numpy as np
import os
import tensorflow as tf

from ppo.history import *
from ppo.models import *
from ppo.trainer import Trainer
from unityagents import *

# %% [markdown]
# ### Hyperparameters

# %%
### General parameters
max_steps = 10000000 # Set maximum number of steps to run environment.
run_path = "ppo" # The sub-directory name for model and summary statistics
load_model = False # Whether to load a saved model.
train_model = True # Whether to train the model.
summary_freq = 10000 # Frequency at which to save training statistics.
save_freq = 50000 # Frequency at which to save model.
env_name = "tictac" # Name of the training environment file.
curriculum_file = None

### Algorithm-specific parameters for tuning
gamma = 0.99 # Reward discount rate.
lambd = 0.95 # Lambda parameter for GAE.
time_horizon = 64 # How many steps to collect per agent before adding to buffer.
beta = 1e-2 # Strength of entropy regularization
num_epoch = 5 # Number of gradient descent steps per batch of experiences.
num_layers = 2 # Number of hidden layers between state/observation encoding and value/policy layers.
epsilon = 0.3 # Acceptable threshold around ratio of old and new policy probabilities.
buffer_size = 4096 # How large the experience buffer should be before gradient descent.
learning_rate = 3e-4 # Model learning rate.
hidden_units = 27 # Number of units in hidden layer.
batch_size = 32 # How many experiences per gradient descent update step.
normalize = True

### Logging dictionary for hyperparameters
hyperparameter_dict = {'max_steps':max_steps, 'run_path':run_path, 'env_name':env_name,
    'curriculum_file':curriculum_file, 'gamma':gamma, 'lambd':lambd, 'time_horizon':time_horizon,
    'beta':beta, 'num_epoch':num_epoch, 'epsilon':epsilon, 'buffe_size':buffer_size,
    'leaning_rate':learning_rate, 'hidden_units':hidden_units, 'batch_size':batch_size}

# %% [markdown]
# ### Load the environment

# %%
env = UnityEnvironment(file_name=env_name, curriculum=curriculum_file)
print(str(env))
brain_name = env.external_brain_names[0]
# Out:
# INFO:unityagents:
# 'Academy' started successfully!
# Unity Academy name: Academy
#         Number of brains: 1
#         Reset Parameters :
# 		defence_penalty -> -0.5
# 		defence_reward -> 0.5
# Unity brain name: Brain
#         Number of observations (per agent): 0
#         State space type: continuous
#         State space size (per agent): 10
#         Action space type: discrete
#         Action space size (per agent): 9
#         Memory space size (per agent): 0
#         Action descriptions: 0, 1, 2, 3, 4, 5, 6, 7, 8

# %% [markdown]
# ### Train the Agent(s)

# %%
tf.reset_default_graph()

if curriculum_file == "None":
    curriculum_file = None


def get_progress():
    if curriculum_file is not None:
        if env._curriculum.measure_type == "progress":
            return steps / max_steps
        elif env._curriculum.measure_type == "reward":
            return last_reward
        else:
            return None
    else:
        return None

# Create the Tensorflow model graph
ppo_model = create_agent_model(env, lr=learning_rate,
                               h_size=hidden_units, epsilon=epsilon,
                               beta=beta, max_step=max_steps, 
                               normalize=normalize, num_layers=num_layers)

is_continuous = (env.brains[brain_name].action_space_type == "continuous")
use_observations = (env.brains[brain_name].number_observations > 0)
use_states = (env.brains[brain_name].state_space_size > 0)

model_path = './models/{}'.format(run_path)
summary_path = './summaries/{}'.format(run_path)

if not os.path.exists(model_path):
    os.makedirs(model_path)

if not os.path.exists(summary_path):
    os.makedirs(summary_path)

init = tf.global_variables_initializer()
saver = tf.train.Saver()

with tf.Session() as sess:
    # Instantiate model parameters
    if load_model:
        print('Loading Model...')
        ckpt = tf.train.get_checkpoint_state(model_path)
        saver.restore(sess, ckpt.model_checkpoint_path)
    else:
        sess.run(init)
    steps, last_reward = sess.run([ppo_model.global_step, ppo_model.last_reward])    
    summary_writer = tf.summary.FileWriter(summary_path)
    info = env.reset(train_mode=train_model, progress=get_progress())[brain_name]
    trainer = Trainer(ppo_model, sess, info, is_continuous, use_observations, use_states, train_model)
    if train_model:
        trainer.write_text(summary_writer, 'Hyperparameters', hyperparameter_dict, steps)
    while steps <= max_steps:
        if env.global_done:
            info = env.reset(train_mode=train_model, progress=get_progress())[brain_name]
        # Decide and take an action
        new_info = trainer.take_action(info, env, brain_name, steps, normalize)
        info = new_info
        trainer.process_experiences(info, time_horizon, gamma, lambd)
        if len(trainer.training_buffer['actions']) > buffer_size and train_model:
            # Perform gradient descent with experience buffer
            trainer.update_model(batch_size, num_epoch)
        if steps % summary_freq == 0 and steps != 0 and train_model:
            # Write training statistics to tensorboard.
            trainer.write_summary(summary_writer, steps, env._curriculum.lesson_number)
        if steps % save_freq == 0 and steps != 0 and train_model:
            # Save Tensorflow model
            save_model(sess, model_path=model_path, steps=steps, saver=saver)
        steps += 1
        sess.run(ppo_model.increment_step)
        if len(trainer.stats['cumulative_reward']) > 0:
            mean_reward = np.mean(trainer.stats['cumulative_reward'])
            sess.run(ppo_model.update_reward, feed_dict={ppo_model.new_reward: mean_reward})
            last_reward = sess.run(ppo_model.last_reward)
    # Final save Tensorflow model
    if steps != 0 and train_model:
        save_model(sess, model_path=model_path, steps=steps, saver=saver)
env.close()
export_graph(model_path, env_name)
# Out:
# Step: 10000. Mean Reward: -1.12950600801. Std of Reward: 0.520203202085.
# Step: 20000. Mean Reward: -1.13077274806. Std of Reward: 0.539309366336.
# Step: 30000. Mean Reward: -1.08160036166. Std of Reward: 0.50869302744.
# Step: 40000. Mean Reward: -1.02829099307. Std of Reward: 0.528333331637.
# Step: 50000. Mean Reward: -0.969452247191. Std of Reward: 0.568955058983.
# Saved Model
# Step: 60000. Mean Reward: -0.913595021541. Std of Reward: 0.609347130942.
# Step: 70000. Mean Reward: -0.807567432567. Std of Reward: 0.686198264818.
# Step: 80000. Mean Reward: -0.707080998472. Std of Reward: 0.697476191901.
# Step: 90000. Mean Reward: -0.640689834025. Std of Reward: 0.782002358072.
# Step: 100000. Mean Reward: -0.519936204147. Std of Reward: 0.885264625327.
# Saved Model
# Step: 110000. Mean Reward: -0.444872476089. Std of Reward: 0.938276570155.
# Step: 120000. Mean Reward: -0.308962264151. Std of Reward: 1.02200341853.
# Step: 130000. Mean Reward: -0.266518600777. Std of Reward: 1.06583563097.
# Step: 140000. Mean Reward: -0.151467203682. Std of Reward: 1.15057742011.
# Step: 150000. Mean Reward: -0.0731132075472. Std of Reward: 1.17694764372.
# Saved Model
# Step: 160000. Mean Reward: -0.0743909512761. Std of Reward: 1.1850643566.
# Step: 170000. Mean Reward: 0.0198107628622. Std of Reward: 1.24737129615.
# Step: 180000. Mean Reward: 0.105381840048. Std of Reward: 1.29083203542.
# Step: 190000. Mean Reward: 0.144817073171. Std of Reward: 1.30170056341.
# Step: 200000. Mean Reward: 0.25796875. Std of Reward: 1.34151521107.
# Saved Model
# Step: 210000. Mean Reward: 0.341862682772. Std of Reward: 1.37670909613.
# Step: 220000. Mean Reward: 0.307156428119. Std of Reward: 1.35568820929.
# Step: 230000. Mean Reward: 0.212330873309. Std of Reward: 1.32948520635.
# Step: 240000. Mean Reward: 0.310235219326. Std of Reward: 1.37691211623.
# Step: 250000. Mean Reward: 0.261047979798. Std of Reward: 1.33337633935.
# Saved Model
# Step: 260000. Mean Reward: 0.280873970868. Std of Reward: 1.34746551992.
# Step: 270000. Mean Reward: 0.330779054917. Std of Reward: 1.34937818553.
# Step: 280000. Mean Reward: 0.328612348822. Std of Reward: 1.34770389052.
# Step: 290000. Mean Reward: 0.434399477807. Std of Reward: 1.38504393506.
# Step: 300000. Mean Reward: 0.442194644024. Std of Reward: 1.37061973186.
# Saved Model
# Step: 310000. Mean Reward: 0.471840209561. Std of Reward: 1.39457953587.
# Step: 320000. Mean Reward: 0.531767041694. Std of Reward: 1.42687409292.
# Step: 330000. Mean Reward: 0.509920634921. Std of Reward: 1.41852730065.
# Step: 340000. Mean Reward: 0.542136695421. Std of Reward: 1.43438074513.
# Step: 350000. Mean Reward: 0.584685598377. Std of Reward: 1.43896693768.
# Saved Model
# Step: 360000. Mean Reward: 0.590709459459. Std of Reward: 1.4452881867.
# Step: 370000. Mean Reward: 0.632482993197. Std of Reward: 1.43439561263.
# Step: 380000. Mean Reward: 0.612372881356. Std of Reward: 1.43117509972.
# Step: 390000. Mean Reward: 0.576561450638. Std of Reward: 1.42798283824.
# Step: 400000. Mean Reward: 0.670588235294. Std of Reward: 1.44479138471.
# Saved Model
# Step: 410000. Mean Reward: 0.681647300068. Std of Reward: 1.43598650123.
# Step: 420000. Mean Reward: 0.663605442177. Std of Reward: 1.456402214.
# Step: 430000. Mean Reward: 0.737880886427. Std of Reward: 1.44967828017.
# Step: 440000. Mean Reward: 0.727588603197. Std of Reward: 1.44049561303.
# Step: 450000. Mean Reward: 0.841264204545. Std of Reward: 1.45136533234.
# Saved Model
# Step: 460000. Mean Reward: 0.870646766169. Std of Reward: 1.45455506168.
# Step: 470000. Mean Reward: 1.02415812592. Std of Reward: 1.48404219814.
# Step: 480000. Mean Reward: 0.871196036801. Std of Reward: 1.47665429648.
# Step: 490000. Mean Reward: 1.08215875371. Std of Reward: 1.4518006363.
# Step: 500000. Mean Reward: 1.00747629468. Std of Reward: 1.46627809685.
# Saved Model
# Step: 510000. Mean Reward: 1.05033432392. Std of Reward: 1.42485169051.
# Step: 520000. Mean Reward: 1.15767790262. Std of Reward: 1.44416916267.
# Step: 530000. Mean Reward: 1.22051089406. Std of Reward: 1.43364505062.
# Step: 540000. Mean Reward: 1.19897959184. Std of Reward: 1.42924749147.
# Step: 550000. Mean Reward: 1.3606870229. Std of Reward: 1.40366896058.
# Saved Model
# Step: 560000. Mean Reward: 1.46669248644. Std of Reward: 1.35589563179.
# Step: 570000. Mean Reward: 1.32586206897. Std of Reward: 1.41526019572.
# Step: 580000. Mean Reward: 1.41595662277. Std of Reward: 1.39487867469.
# Step: 590000. Mean Reward: 1.52254746835. Std of Reward: 1.35969834388.
# Step: 600000. Mean Reward: 1.58857484076. Std of Reward: 1.32523088631.
# Saved Model
# Step: 610000. Mean Reward: 1.62908366534. Std of Reward: 1.33179429822.
# Step: 620000. Mean Reward: 1.63075396825. Std of Reward: 1.31600217823.
# Step: 630000. Mean Reward: 1.75201612903. Std of Reward: 1.28412922664.
# Step: 640000. Mean Reward: 1.74779116466. Std of Reward: 1.30073548108.
# Step: 650000. Mean Reward: 1.7825562701. Std of Reward: 1.27445734971.
# Saved Model
# Step: 660000. Mean Reward: 1.8344785772. Std of Reward: 1.22492538129.
# Step: 670000. Mean Reward: 1.88595413595. Std of Reward: 1.2191085791.
# Step: 680000. Mean Reward: 1.92217175888. Std of Reward: 1.19414072852.
# Step: 690000. Mean Reward: 1.9158496732. Std of Reward: 1.16831379398.
# Step: 700000. Mean Reward: 1.99979355904. Std of Reward: 1.17288997374.
# Saved Model
# Step: 710000. Mean Reward: 2.01160862355. Std of Reward: 1.14132479512.
# Step: 720000. Mean Reward: 2.09448653199. Std of Reward: 1.08753319032.
# Step: 730000. Mean Reward: 2.06244796003. Std of Reward: 1.10188371108.
# Step: 740000. Mean Reward: 2.0875. Std of Reward: 1.09613430594.
# Step: 750000. Mean Reward: 2.13048060708. Std of Reward: 1.05482934453.
# Saved Model
# Step: 760000. Mean Reward: 2.20448772227. Std of Reward: 1.01871406009.
# Step: 770000. Mean Reward: 2.21774193548. Std of Reward: 0.99963881149.
# Step: 780000. Mean Reward: 2.25042662116. Std of Reward: 0.965819333638.
# Step: 790000. Mean Reward: 2.26520994002. Std of Reward: 0.967462304527.
# Step: 800000. Mean Reward: 2.26637931034. Std of Reward: 1.02071805063.
# Saved Model
# Step: 810000. Mean Reward: 2.2951208981. Std of Reward: 0.970842152216.
# Step: 820000. Mean Reward: 2.32167530225. Std of Reward: 0.925460698378.
# Step: 830000. Mean Reward: 2.36485319516. Std of Reward: 0.89759538923.
# Step: 840000. Mean Reward: 2.32422547332. Std of Reward: 0.915965933405.
# Step: 850000. Mean Reward: 2.39267015707. Std of Reward: 0.86080719724.
# Saved Model
# Step: 860000. Mean Reward: 2.3812335958. Std of Reward: 0.85812974964.
# Step: 870000. Mean Reward: 2.36965998256. Std of Reward: 0.858131608923.
# Step: 880000. Mean Reward: 2.38934782609. Std of Reward: 0.858389295929.
# Step: 890000. Mean Reward: 2.36620330148. Std of Reward: 0.909702650662.
# Step: 900000. Mean Reward: 2.3868788143. Std of Reward: 0.898698577682.
# Saved Model
# Step: 910000. Mean Reward: 2.37630434783. Std of Reward: 0.9448219494.
# Step: 920000. Mean Reward: 2.40179352581. Std of Reward: 0.889037848928.
# Step: 930000. Mean Reward: 2.43612818262. Std of Reward: 0.809454029291.
# Step: 940000. Mean Reward: 2.40223097113. Std of Reward: 0.878319505648.
# Step: 950000. Mean Reward: 2.44986807388. Std of Reward: 0.836393228423.
# Saved Model
# Step: 960000. Mean Reward: 2.43156059285. Std of Reward: 0.877527489982.
# Step: 970000. Mean Reward: 2.44920844327. Std of Reward: 0.838814491784.
# Step: 980000. Mean Reward: 2.49867139061. Std of Reward: 0.827183214318.
# Step: 990000. Mean Reward: 2.55026929982. Std of Reward: 0.775051350132.
# Step: 1000000. Mean Reward: 2.5089047195. Std of Reward: 0.850480955966.
# Saved Model
# Step: 1010000. Mean Reward: 2.5681205036. Std of Reward: 0.72292395135.
# Step: 1020000. Mean Reward: 2.54561717352. Std of Reward: 0.722079289988.
# Step: 1030000. Mean Reward: 2.57580500894. Std of Reward: 0.738136963339.
# Step: 1040000. Mean Reward: 2.56789568345. Std of Reward: 0.793265763696.
# Step: 1050000. Mean Reward: 2.57450628366. Std of Reward: 0.765953002608.
# Saved Model
# Step: 1060000. Mean Reward: 2.63830755232. Std of Reward: 0.711821569825.
# Step: 1070000. Mean Reward: 2.66954545455. Std of Reward: 0.699597139091.
# Step: 1080000. Mean Reward: 2.61665162455. Std of Reward: 0.77477740924.
# Step: 1090000. Mean Reward: 2.67873406193. Std of Reward: 0.707580564547.
# Step: 1100000. Mean Reward: 2.71438356164. Std of Reward: 0.624544370107.
# Saved Model
# Step: 1110000. Mean Reward: 2.72779304029. Std of Reward: 0.651515548764.
# Step: 1120000. Mean Reward: 2.75854108957. Std of Reward: 0.601904100031.
# Step: 1130000. Mean Reward: 2.7371559633. Std of Reward: 0.62950773216.
# Step: 1140000. Mean Reward: 2.82597583643. Std of Reward: 0.511236633397.
# Step: 1150000. Mean Reward: 2.78026802218. Std of Reward: 0.592385620174.
# Saved Model
# Step: 1160000. Mean Reward: 2.81464318814. Std of Reward: 0.574039583639.
# Step: 1170000. Mean Reward: 2.83589385475. Std of Reward: 0.561210277612.
# Step: 1180000. Mean Reward: 2.87348272642. Std of Reward: 0.455392945959.
# Step: 1190000. Mean Reward: 2.87663246269. Std of Reward: 0.43233587947.
# Step: 1200000. Mean Reward: 2.89165103189. Std of Reward: 0.447644129403.
# Saved Model
# Step: 1210000. Mean Reward: 2.90662931839. Std of Reward: 0.405998362375.
# Step: 1220000. Mean Reward: 2.90262172285. Std of Reward: 0.458735090356.
# Step: 1230000. Mean Reward: 2.92011278195. Std of Reward: 0.37806962509.
# Step: 1240000. Mean Reward: 2.88341121495. Std of Reward: 0.508473112041.
# Step: 1250000. Mean Reward: 2.91384976526. Std of Reward: 0.410579821272.
# Saved Model
# Step: 1260000. Mean Reward: 2.91980244591. Std of Reward: 0.420517598136.
# Step: 1270000. Mean Reward: 2.91471415183. Std of Reward: 0.423771157825.
# Step: 1280000. Mean Reward: 2.9388523048. Std of Reward: 0.311507728209.
# Step: 1290000. Mean Reward: 2.93461900282. Std of Reward: 0.404095939607.
# Step: 1300000. Mean Reward: 2.94716981132. Std of Reward: 0.323660533546.
# Saved Model
# Step: 1310000. Mean Reward: 2.93461900282. Std of Reward: 0.348300565339.
# Step: 1320000. Mean Reward: 2.93490566038. Std of Reward: 0.367787226437.
# Step: 1330000. Mean Reward: 2.95353773585. Std of Reward: 0.306030941663.
# Step: 1340000. Mean Reward: 2.93979303857. Std of Reward: 0.375673436664.
# Step: 1350000. Mean Reward: 2.94948064212. Std of Reward: 0.340696135584.
# Saved Model
# Step: 1360000. Mean Reward: 2.95471698113. Std of Reward: 0.302819167495.
# Step: 1370000. Mean Reward: 2.94669811321. Std of Reward: 0.333100703505.
# Step: 1380000. Mean Reward: 2.95117924528. Std of Reward: 0.355596795653.
# Step: 1390000. Mean Reward: 2.95566037736. Std of Reward: 0.287172352653.
# Step: 1400000. Mean Reward: 2.96462488129. Std of Reward: 0.2455584113.
# Saved Model
# Step: 1410000. Mean Reward: 2.95613207547. Std of Reward: 0.312793472024.
# Step: 1420000. Mean Reward: 2.9547596607. Std of Reward: 0.307314940848.
# Step: 1430000. Mean Reward: 2.9516509434. Std of Reward: 0.319691199543.
# Step: 1440000. Mean Reward: 2.96081208687. Std of Reward: 0.261873293622.
# Step: 1450000. Mean Reward: 2.9606873823. Std of Reward: 0.276676873767.
# Saved Model
# Step: 1460000. Mean Reward: 2.9358490566. Std of Reward: 0.364248691544.
# Step: 1470000. Mean Reward: 2.97072710104. Std of Reward: 0.234213650582.
# Step: 1480000. Mean Reward: 2.94914853359. Std of Reward: 0.321794627209.
# Step: 1490000. Mean Reward: 2.94462770971. Std of Reward: 0.339351793734.
# Step: 1500000. Mean Reward: 2.96922348485. Std of Reward: 0.279719765165.
# Saved Model
# Step: 1510000. Mean Reward: 2.98062381853. Std of Reward: 0.166564270536.
# Step: 1520000. Mean Reward: 2.97540208136. Std of Reward: 0.215001384157.
# Step: 1530000. Mean Reward: 2.98107852412. Std of Reward: 0.191460478771.
# Step: 1540000. Mean Reward: 2.98674242424. Std of Reward: 0.159349987459.
# Step: 1550000. Mean Reward: 2.97602089269. Std of Reward: 0.213964139366.
# Saved Model
# Step: 1560000. Mean Reward: 2.95837275307. Std of Reward: 0.330087573506.
# Step: 1570000. Mean Reward: 2.95971563981. Std of Reward: 0.30171376959.
# Step: 1580000. Mean Reward: 2.97729422895. Std of Reward: 0.205079908036.
# Step: 1590000. Mean Reward: 2.96132075472. Std of Reward: 0.277138598497.
# Step: 1600000. Mean Reward: 2.9625. Std of Reward: 0.265903364132.
# Saved Model
# Step: 1610000. Mean Reward: 2.97843601896. Std of Reward: 0.216218950446.
# Step: 1620000. Mean Reward: 2.9628666036. Std of Reward: 0.280398780411.
# Step: 1630000. Mean Reward: 2.98248106061. Std of Reward: 0.168341676646.
# Step: 1640000. Mean Reward: 2.962700661. Std of Reward: 0.309247886106.
# Step: 1650000. Mean Reward: 2.9634088763. Std of Reward: 0.286449717998.
# Saved Model
# Step: 1660000. Mean Reward: 2.98055028463. Std of Reward: 0.158117725804.
# Step: 1670000. Mean Reward: 2.96259469697. Std of Reward: 0.280814040111.
# Step: 1680000. Mean Reward: 2.96803977273. Std of Reward: 0.2466323219.
# Step: 1690000. Mean Reward: 2.97324810606. Std of Reward: 0.231935938036.
# Step: 1700000. Mean Reward: 2.97464454976. Std of Reward: 0.207978858081.
# Saved Model
# Step: 1710000. Mean Reward: 2.97017045455. Std of Reward: 0.241935005121.
# Step: 1720000. Mean Reward: 2.98766603416. Std of Reward: 0.148808227148.
# Step: 1730000. Mean Reward: 2.97772511848. Std of Reward: 0.200358778395.
# Step: 1740000. Mean Reward: 2.97358490566. Std of Reward: 0.232420360388.
# Step: 1750000. Mean Reward: 2.97563859981. Std of Reward: 0.247380207041.
# Saved Model
# Step: 1760000. Mean Reward: 2.98106060606. Std of Reward: 0.226387163598.
# Step: 1770000. Mean Reward: 2.97731568998. Std of Reward: 0.219458813132.
# Step: 1780000. Mean Reward: 2.97639282342. Std of Reward: 0.225362619525.
# Step: 1790000. Mean Reward: 2.9853219697. Std of Reward: 0.143176525826.
# Step: 1800000. Mean Reward: 2.97535545024. Std of Reward: 0.250798235982.
# Saved Model
# Step: 1810000. Mean Reward: 2.97894985809. Std of Reward: 0.237445675393.
# Step: 1820000. Mean Reward: 2.97258979206. Std of Reward: 0.227649500038.
# Step: 1830000. Mean Reward: 2.98671726755. Std of Reward: 0.159500054266.
# Step: 1840000. Mean Reward: 2.97770398482. Std of Reward: 0.21251418893.
# Step: 1850000. Mean Reward: 2.97894985809. Std of Reward: 0.227786299506.
# Saved Model
# Step: 1860000. Mean Reward: 2.97253787879. Std of Reward: 0.252269243651.
# Step: 1870000. Mean Reward: 2.97227488152. Std of Reward: 0.238977958658.
# Step: 1880000. Mean Reward: 2.97755198488. Std of Reward: 0.254039872361.
# Step: 1890000. Mean Reward: 2.97492904447. Std of Reward: 0.252631598159.
# Step: 1900000. Mean Reward: 2.98436018957. Std of Reward: 0.139368729546.
# Saved Model
# Step: 1910000. Mean Reward: 2.97914691943. Std of Reward: 0.215877427543.
# Step: 1920000. Mean Reward: 2.99099526066. Std of Reward: 0.131215444474.
# Step: 1930000. Mean Reward: 2.97395833333. Std of Reward: 0.25844423481.
# Step: 1940000. Mean Reward: 2.97400756144. Std of Reward: 0.24697643815.
# Step: 1950000. Mean Reward: 2.99053030303. Std of Reward: 0.132019938772.
# Saved Model
# Step: 1960000. Mean Reward: 2.99360189573. Std of Reward: 0.110016426159.
# Step: 1970000. Mean Reward: 2.99099526066. Std of Reward: 0.13825059662.
# Step: 1980000. Mean Reward: 2.97867298578. Std of Reward: 0.256008630964.
# Step: 1990000. Mean Reward: 2.98529411765. Std of Reward: 0.182284831499.
# Step: 2000000. Mean Reward: 2.98104265403. Std of Reward: 0.225445011382.
# Saved Model
# Step: 2010000. Mean Reward: 2.97438330171. Std of Reward: 0.237961275105.
# Step: 2020000. Mean Reward: 2.98717948718. Std of Reward: 0.136350907124.
# Step: 2030000. Mean Reward: 2.98719165085. Std of Reward: 0.181123122933.
# Step: 2040000. Mean Reward: 2.98674242424. Std of Reward: 0.151739890144.
# Step: 2050000. Mean Reward: 2.98483412322. Std of Reward: 0.18665767123.
# Saved Model
# Step: 2060000. Mean Reward: 2.98336501901. Std of Reward: 0.186163201207.
# Step: 2070000. Mean Reward: 2.98197343454. Std of Reward: 0.179029894931.
# Step: 2080000. Mean Reward: 2.97224857685. Std of Reward: 0.267864155425.
# Step: 2090000. Mean Reward: 2.98036896878. Std of Reward: 0.219453945408.
# Step: 2100000. Mean Reward: 2.98369565217. Std of Reward: 0.219083090986.
# Saved Model
# Step: 2110000. Mean Reward: 2.97677725118. Std of Reward: 0.251641139679.
# Step: 2120000. Mean Reward: 2.98579545455. Std of Reward: 0.189164159854.
# Step: 2130000. Mean Reward: 2.98765432099. Std of Reward: 0.126459217487.
# Step: 2140000. Mean Reward: 2.99479166667. Std of Reward: 0.0934470061632.
# Step: 2150000. Mean Reward: 2.98670465337. Std of Reward: 0.181828491524.
# Saved Model
# Step: 2160000. Mean Reward: 2.97651802657. Std of Reward: 0.246861362727.
# Step: 2170000. Mean Reward: 2.98770104068. Std of Reward: 0.174917505976.
# Step: 2180000. Mean Reward: 2.97393364929. Std of Reward: 0.26735172239.
# Step: 2190000. Mean Reward: 2.99099526066. Std of Reward: 0.131215444474.
# Step: 2200000. Mean Reward: 2.9864800759. Std of Reward: 0.156666656484.
# Saved Model
# Step: 2210000. Mean Reward: 2.98671726755. Std of Reward: 0.156497606076.
# Step: 2220000. Mean Reward: 2.98816287879. Std of Reward: 0.15721907361.
# Step: 2230000. Mean Reward: 2.98436018957. Std of Reward: 0.189766489403.
# Step: 2240000. Mean Reward: 2.9710626186. Std of Reward: 0.289756178774.
# Step: 2250000. Mean Reward: 2.98484848485. Std of Reward: 0.195250363165.
# Saved Model
# Step: 2260000. Mean Reward: 2.99049429658. Std of Reward: 0.104121085942.
# Step: 2270000. Mean Reward: 2.99762808349. Std of Reward: 0.046142159353.
# Step: 2280000. Mean Reward: 2.97798295455. Std of Reward: 0.243379387428.
# Step: 2290000. Mean Reward: 2.98907882241. Std of Reward: 0.177361709856.
# Step: 2300000. Mean Reward: 2.9855450237. Std of Reward: 0.176436720156.
# Saved Model
# Step: 2310000. Mean Reward: 2.98837760911. Std of Reward: 0.168485061786.
# Step: 2320000. Mean Reward: 2.9836492891. Std of Reward: 0.223671327585.
# Step: 2330000. Mean Reward: 2.98838862559. Std of Reward: 0.161216526453.
# Step: 2340000. Mean Reward: 2.99195075758. Std of Reward: 0.113824615219.
# Step: 2350000. Mean Reward: 2.98814041746. Std of Reward: 0.185073335939.
# Saved Model
# Step: 2360000. Mean Reward: 2.99809885932. Std of Reward: 0.0435606054654.
# Step: 2370000. Mean Reward: 2.9817535545. Std of Reward: 0.227204849266.
# Step: 2380000. Mean Reward: 2.99335232669. Std of Reward: 0.115113661518.
# Step: 2390000. Mean Reward: 2.9943019943. Std of Reward: 0.132425011358.
# Step: 2400000. Mean Reward: 2.99573055028. Std of Reward: 0.0828271071201.
# Saved Model
# Step: 2410000. Mean Reward: 2.98578199052. Std of Reward: 0.183209226619.
# Step: 2420000. Mean Reward: 2.99096958175. Std of Reward: 0.13140152317.
# Step: 2430000. Mean Reward: 2.9869544592. Std of Reward: 0.172211102895.
# Step: 2440000. Mean Reward: 2.99572649573. Std of Reward: 0.0856834942554.
# Step: 2450000. Mean Reward: 2.97817836812. Std of Reward: 0.268522739341.
# Saved Model
# Step: 2460000. Mean Reward: 2.99239543726. Std of Reward: 0.119166798055.
# Step: 2470000. Mean Reward: 2.97918637654. Std of Reward: 0.26287490736.
# Step: 2480000. Mean Reward: 2.99243140965. Std of Reward: 0.155137352629.
# Step: 2490000. Mean Reward: 2.9943019943. Std of Reward: 0.0842023743939.
# Step: 2500000. Mean Reward: 2.98557237465. Std of Reward: 0.201325970432.
# Saved Model
# Step: 2510000. Mean Reward: 2.98672985782. Std of Reward: 0.208104098107.
# Step: 2520000. Mean Reward: 2.98788022814. Std of Reward: 0.167904703499.
# Step: 2530000. Mean Reward: 2.99479166667. Std of Reward: 0.0855095808398.
# Step: 2540000. Mean Reward: 2.99052132701. Std of Reward: 0.130275731174.
# Step: 2550000. Mean Reward: 2.99147727273. Std of Reward: 0.145719529582.
# Saved Model
# Step: 2560000. Mean Reward: 2.99762808349. Std of Reward: 0.0554785136172.
# Step: 2570000. Mean Reward: 2.99120722433. Std of Reward: 0.154098527889.
# Step: 2580000. Mean Reward: 2.98199052133. Std of Reward: 0.225259870791.
# Step: 2590000. Mean Reward: 2.98483412322. Std of Reward: 0.187607399817.
# Step: 2600000. Mean Reward: 2.99596391263. Std of Reward: 0.0913928655186.
# Saved Model
# Step: 2610000. Mean Reward: 2.98744075829. Std of Reward: 0.161145455613.
# Step: 2620000. Mean Reward: 2.98458254269. Std of Reward: 0.202421222568.
# Step: 2630000. Mean Reward: 2.99264705882. Std of Reward: 0.150128075322.
# Step: 2640000. Mean Reward: 2.97944234405. Std of Reward: 0.249981797037.
# Step: 2650000. Mean Reward: 2.99048525214. Std of Reward: 0.124935197366.
# Saved Model
# Step: 2660000. Mean Reward: 2.99289772727. Std of Reward: 0.134828499913.
# Step: 2670000. Mean Reward: 2.9933396765. Std of Reward: 0.141197062983.
# Step: 2680000. Mean Reward: 2.98958333333. Std of Reward: 0.177806012002.
# Step: 2690000. Mean Reward: 2.9943019943. Std of Reward: 0.115164575108.
# Step: 2700000. Mean Reward: 2.98884140551. Std of Reward: 0.169999124389.
# Saved Model
# Step: 2710000. Mean Reward: 2.97983870968. Std of Reward: 0.258873036695.
# Step: 2720000. Mean Reward: 2.98410815939. Std of Reward: 0.21571625468.
# Step: 2730000. Mean Reward: 2.99287749288. Std of Reward: 0.133249906936.
# Step: 2740000. Mean Reward: 2.98841059603. Std of Reward: 0.176480170335.
# Step: 2750000. Mean Reward: 2.99572649573. Std of Reward: 0.0670272954759.
# Saved Model
# Step: 2760000. Mean Reward: 2.98363377609. Std of Reward: 0.205545007554.
# Step: 2770000. Mean Reward: 2.99480151229. Std of Reward: 0.107477558732.
# Step: 2780000. Mean Reward: 2.99005681818. Std of Reward: 0.164701280879.
# Step: 2790000. Mean Reward: 2.98461174242. Std of Reward: 0.196591313925.
# Step: 2800000. Mean Reward: 2.99477186312. Std of Reward: 0.0961287023799.
# Saved Model
# Step: 2810000. Mean Reward: 2.99429657795. Std of Reward: 0.128850502387.
# Step: 2820000. Mean Reward: 2.99074074074. Std of Reward: 0.154766687812.
# Step: 2830000. Mean Reward: 2.99051233397. Std of Reward: 0.139139137425.
# Step: 2840000. Mean Reward: 2.98979107312. Std of Reward: 0.174876849997.
# Step: 2850000. Mean Reward: 2.98312737643. Std of Reward: 0.232797932361.
# Saved Model
# Step: 2860000. Mean Reward: 2.99240986717. Std of Reward: 0.156876771934.
# Step: 2870000. Mean Reward: 2.99264007597. Std of Reward: 0.133459557734.
# Step: 2880000. Mean Reward: 2.98907882241. Std of Reward: 0.164874715617.
# Step: 2890000. Mean Reward: 2.9874288425. Std of Reward: 0.169819449169.
# Step: 2900000. Mean Reward: 2.98319128788. Std of Reward: 0.217627847657.
# Saved Model
# Step: 2910000. Mean Reward: 2.99098671727. Std of Reward: 0.123839484979.
# Step: 2920000. Mean Reward: 2.99383301708. Std of Reward: 0.135002686778.
# Step: 2930000. Mean Reward: 2.98219373219. Std of Reward: 0.204365073033.
# Step: 2940000. Mean Reward: 2.99573055028. Std of Reward: 0.0768866898135.
# Step: 2950000. Mean Reward: 2.98694207028. Std of Reward: 0.163453219175.
# Saved Model
# Step: 2960000. Mean Reward: 2.99407020873. Std of Reward: 0.121367284888.
# Step: 2970000. Mean Reward: 2.99715370019. Std of Reward: 0.0532747443695.
# Step: 2980000. Mean Reward: 2.98859315589. Std of Reward: 0.175395039922.
# Step: 2990000. Mean Reward: 2.99287749288. Std of Reward: 0.138492018265.
# Step: 3000000. Mean Reward: 2.9874288425. Std of Reward: 0.17800265483.
# Saved Model
# Step: 3010000. Mean Reward: 2.98151658768. Std of Reward: 0.222575560331.
# Step: 3020000. Mean Reward: 2.99431818182. Std of Reward: 0.0946780284087.
# Step: 3030000. Mean Reward: 2.99667616334. Std of Reward: 0.0829098445801.
# Step: 3040000. Mean Reward: 2.98788022814. Std of Reward: 0.186670784678.
# Step: 3050000. Mean Reward: 2.99335863378. Std of Reward: 0.142668757015.
# Saved Model
# Step: 3060000. Mean Reward: 2.98838862559. Std of Reward: 0.151361156447.
# Step: 3070000. Mean Reward: 2.99525616698. Std of Reward: 0.0922843187061.
# Step: 3080000. Mean Reward: 2.99336492891. Std of Reward: 0.0995418628854.
# Step: 3090000. Mean Reward: 2.98886255924. Std of Reward: 0.156021735851.
# Step: 3100000. Mean Reward: 2.99904852521. Std of Reward: 0.0217906422276.
# Saved Model
# Step: 3110000. Mean Reward: 2.99335232669. Std of Reward: 0.108750419051.
# Step: 3120000. Mean Reward: 2.9981042654. Std of Reward: 0.0434987446657.
# Step: 3130000. Mean Reward: 2.984375. Std of Reward: 0.218665432788.
# Step: 3140000. Mean Reward: 2.99238820171. Std of Reward: 0.139453553695.
# Step: 3150000. Mean Reward: 2.98885199241. Std of Reward: 0.158732260916.
# Saved Model
# Step: 3160000. Mean Reward: 2.99667931689. Std of Reward: 0.0828705673833.
# Step: 3170000. Mean Reward: 2.99454459203. Std of Reward: 0.118422311399.
# Step: 3180000. Mean Reward: 2.98770104068. Std of Reward: 0.187953459307.
# Step: 3190000. Mean Reward: 2.99358974359. Std of Reward: 0.120418827381.
# Step: 3200000. Mean Reward: 2.99620493359. Std of Reward: 0.0721374645361.
# Saved Model
# Step: 3210000. Mean Reward: 2.99288425047. Std of Reward: 0.113995205626.
# Step: 3220000. Mean Reward: 2.99241706161. Std of Reward: 0.135742076629.
# Step: 3230000. Mean Reward: 2.99620493359. Std of Reward: 0.0870386712803.
# Step: 3240000. Mean Reward: 2.99026590693. Std of Reward: 0.155502816292.
# Step: 3250000. Mean Reward: 2.99714557564. Std of Reward: 0.0924939205291.
# Saved Model
# Step: 3260000. Mean Reward: 2.99430740038. Std of Reward: 0.0972381630005.
# Step: 3270000. Mean Reward: 2.99120722433. Std of Reward: 0.142896326404.
# Step: 3280000. Mean Reward: 2.9824311491. Std of Reward: 0.215276002217.
# Step: 3290000. Mean Reward: 2.99857685009. Std of Reward: 0.0344083260072.
# Step: 3300000. Mean Reward: 2.99050332384. Std of Reward: 0.163153960575.
# Saved Model
# Step: 3310000. Mean Reward: 2.9990530303. Std of Reward: 0.0307582988048.
# Step: 3320000. Mean Reward: 2.99904852521. Std of Reward: 0.030831306843.
# Step: 3330000. Mean Reward: 2.99620853081. Std of Reward: 0.0753181820865.
# Step: 3340000. Mean Reward: 2.99714013346. Std of Reward: 0.0925819679098.
# Step: 3350000. Mean Reward: 2.99810066477. Std of Reward: 0.0435399558836.
# Saved Model
# Step: 3360000. Mean Reward: 2.99004739336. Std of Reward: 0.167630539443.
# Step: 3370000. Mean Reward: 2.99288425047. Std of Reward: 0.145118651574.
# Step: 3380000. Mean Reward: 2.99715370019. Std of Reward: 0.0923623192007.
# Step: 3390000. Mean Reward: 2.98789173789. Std of Reward: 0.176108939721.
# Step: 3400000. Mean Reward: 2.99667931689. Std of Reward: 0.0634131778748.
# Saved Model
# Step: 3410000. Mean Reward: 2.99620132953. Std of Reward: 0.0973768261243.
# Step: 3420000. Mean Reward: 2.99144486692. Std of Reward: 0.142702740182.
# Step: 3430000. Mean Reward: 2.99619771863. Std of Reward: 0.0754252259501.
# Step: 3440000. Mean Reward: 2.99619771863. Std of Reward: 0.0974230264283.
# Step: 3450000. Mean Reward: 2.99335863378. Std of Reward: 0.140996421679.
# Saved Model
# Step: 3460000. Mean Reward: 2.99407020873. Std of Reward: 0.1045703181.
# Step: 3470000. Mean Reward: 2.99571836346. Std of Reward: 0.0962213424936.
# Step: 3480000. Mean Reward: 2.99643874644. Std of Reward: 0.0773439997749.
# Step: 3490000. Mean Reward: 2.99382129278. Std of Reward: 0.112057487975.
# Step: 3500000. Mean Reward: 2.99668246445. Std of Reward: 0.0554036341614.
# Saved Model
# Step: 3510000. Mean Reward: 2.99169829222. Std of Reward: 0.165128493631.
# Step: 3520000. Mean Reward: 2.99478178368. Std of Reward: 0.116158057478.
# Step: 3530000. Mean Reward: 2.99810066477. Std of Reward: 0.061604082584.
# Step: 3540000. Mean Reward: 2.99904852521. Std of Reward: 0.030831306843.
# Step: 3550000. Mean Reward: 3.0. Std of Reward: 0.0.
# Saved Model
# Step: 3560000. Mean Reward: 2.99405893536. Std of Reward: 0.113387891845.
# Step: 3570000. Mean Reward: 2.98999046711. Std of Reward: 0.179090222573.
# Step: 3580000. Mean Reward: 2.99121557455. Std of Reward: 0.164822400216.
# Step: 3590000. Mean Reward: 2.99215779468. Std of Reward: 0.144604488141.
# Step: 3600000. Mean Reward: 2.99215779468. Std of Reward: 0.147854754177.
# Saved Model
# Step: 3610000. Mean Reward: 2.99761904762. Std of Reward: 0.0771149273367.
# Step: 3620000. Mean Reward: 2.9990521327. Std of Reward: 0.0307728589208.
# Step: 3630000. Mean Reward: 2.98407794677. Std of Reward: 0.215920096843.
# Step: 3640000. Mean Reward: 2.98529411765. Std of Reward: 0.226132106155.
# Step: 3650000. Mean Reward: 2.99668874172. Std of Reward: 0.0934891339186.
# Saved Model
# Step: 3660000. Mean Reward: 2.99407582938. Std of Reward: 0.119340501873.
# Step: 3670000. Mean Reward: 2.99382129278. Std of Reward: 0.141571967762.
# Step: 3680000. Mean Reward: 2.99261904762. Std of Reward: 0.140594986089.
# Step: 3690000. Mean Reward: 2.99025665399. Std of Reward: 0.171558032349.
# Step: 3700000. Mean Reward: 2.99523809524. Std of Reward: 0.125266156552.
# Saved Model
# Step: 3710000. Mean Reward: 2.99453422053. Std of Reward: 0.128167368328.
# Step: 3720000. Mean Reward: 2.99573055028. Std of Reward: 0.11203985583.
# Step: 3730000. Mean Reward: 2.98909952607. Std of Reward: 0.170376345481.
# Step: 3740000. Mean Reward: 2.9971563981. Std of Reward: 0.0923185767625.
# Step: 3750000. Mean Reward: 2.99619771863. Std of Reward: 0.0974230264283.
# Saved Model
# Step: 3760000. Mean Reward: 2.99905033238. Std of Reward: 0.030802041292.
# Step: 3770000. Mean Reward: 2.9990521327. Std of Reward: 0.0307728589208.
# Step: 3780000. Mean Reward: 2.99714285714. Std of Reward: 0.0689473820866.
# Step: 3790000. Mean Reward: 2.99596774194. Std of Reward: 0.102369289561.
# Step: 3800000. Mean Reward: 2.99336492891. Std of Reward: 0.140929731078.
# Saved Model
# Step: 3810000. Mean Reward: 3.0. Std of Reward: 0.0.
# Step: 3820000. Mean Reward: 2.99573055028. Std of Reward: 0.0985222283758.
# Step: 3830000. Mean Reward: 2.99762583096. Std of Reward: 0.0461640060883.
# Step: 3840000. Mean Reward: 2.99169040836. Std of Reward: 0.153279412894.
# Step: 3850000. Mean Reward: 3.0. Std of Reward: 0.0.
# Saved Model
# Step: 3860000. Mean Reward: 3.0. Std of Reward: 0.0.
# Step: 3870000. Mean Reward: 2.99477186312. Std of Reward: 0.0884017641676.
# Step: 3880000. Mean Reward: 2.99525166192. Std of Reward: 0.12697166126.
# Step: 3890000. Mean Reward: 2.99240265907. Std of Reward: 0.156951070195.
# Step: 3900000. Mean Reward: 2.99691650854. Std of Reward: 0.100059179134.
# Saved Model
# Step: 3910000. Mean Reward: 2.99572243346. Std of Reward: 0.112146152224.
# Step: 3920000. Mean Reward: 2.99621212121. Std of Reward: 0.0972386185833.
# Step: 3930000. Mean Reward: 2.99715370019. Std of Reward: 0.0688166520144.
# Step: 3940000. Mean Reward: 2.99667931689. Std of Reward: 0.0828705673833.
# Step: 3950000. Mean Reward: 2.9881291548. Std of Reward: 0.187707756213.
# Saved Model
# Step: 3960000. Mean Reward: 2.9943019943. Std of Reward: 0.0972841656921.
# Step: 3970000. Mean Reward: 2.99904852521. Std of Reward: 0.030831306843.
# Step: 3980000. Mean Reward: 2.98672985782. Std of Reward: 0.215927884243.
# Step: 3990000. Mean Reward: 2.99098671727. Std of Reward: 0.169171364266.
# Step: 4000000. Mean Reward: 2.99097815764. Std of Reward: 0.174772386226.
# Saved Model
# Step: 4010000. Mean Reward: 2.99525166192. Std of Reward: 0.11100960453.
# Step: 4020000. Mean Reward: 3.0. Std of Reward: 0.0.
# Step: 4030000. Mean Reward: 2.99241706161. Std of Reward: 0.150636364173.
# Step: 4040000. Mean Reward: 2.99002849003. Std of Reward: 0.177417635065.
# Step: 4050000. Mean Reward: 2.98815165877. Std of Reward: 0.190040892917.
# Saved Model
# Step: 4060000. Mean Reward: 2.9990521327. Std of Reward: 0.0307728589208.
# Step: 4070000. Mean Reward: 2.99715370019. Std of Reward: 0.0688166520144.
# Step: 4080000. Mean Reward: 2.99667931689. Std of Reward: 0.0634131778748.
# Step: 4090000. Mean Reward: 2.99904852521. Std of Reward: 0.030831306843.
# Step: 4100000. Mean Reward: 3.0. Std of Reward: 0.0.
# Saved Model
# Step: 4110000. Mean Reward: 2.99715099715. Std of Reward: 0.0575822875539.
# Step: 4120000. Mean Reward: 2.99193548387. Std of Reward: 0.166392267637.
# Step: 4130000. Mean Reward: 2.99809705043. Std of Reward: 0.0435812844552.
# Step: 4140000. Mean Reward: 2.99572649573. Std of Reward: 0.124152470481.
# Step: 4150000. Mean Reward: 2.99905033238. Std of Reward: 0.030802041292.
# Saved Model
# Step: 4160000. Mean Reward: 2.99809885932. Std of Reward: 0.0435606054654.
# Step: 4170000. Mean Reward: 2.99714828897. Std of Reward: 0.092449990936.
# Step: 4180000. Mean Reward: 2.99762131304. Std of Reward: 0.063546122529.
# Step: 4190000. Mean Reward: 2.99572243346. Std of Reward: 0.103322886014.
# Step: 4200000. Mean Reward: 2.99170616114. Std of Reward: 0.155438315923.
# Saved Model
# Step: 4210000. Mean Reward: 2.9943019943. Std of Reward: 0.117207991058.
# Step: 4220000. Mean Reward: 2.99288425047. Std of Reward: 0.111363942901.
# Step: 4230000. Mean Reward: 2.99619410086. Std of Reward: 0.0785499919808.
# Step: 4240000. Mean Reward: 2.99809705043. Std of Reward: 0.0435812844552.
# Step: 4250000. Mean Reward: 2.99266098485. Std of Reward: 0.144356010599.
# Saved Model
# Step: 4260000. Mean Reward: 2.99028436019. Std of Reward: 0.183341585978.
# Step: 4270000. Mean Reward: 2.99857142857. Std of Reward: 0.0344736910433.
# Step: 4280000. Mean Reward: 2.9931344697. Std of Reward: 0.139373343533.
# Step: 4290000. Mean Reward: 3.0. Std of Reward: 0.0.
# Step: 4300000. Mean Reward: 2.99477186312. Std of Reward: 0.107782898814.
# Saved Model
# Step: 4310000. Mean Reward: 2.99431818182. Std of Reward: 0.130434548673.
# Step: 4320000. Mean Reward: 2.99501424501. Std of Reward: 0.11749330581.
# Step: 4330000. Mean Reward: 2.98909952607. Std of Reward: 0.164719047175.
# Step: 4340000. Mean Reward: 3.0. Std of Reward: 0.0.
# Step: 4350000. Mean Reward: 2.99666983825. Std of Reward: 0.107909573951.
# Saved Model
# Step: 4360000. Mean Reward: 2.99904761905. Std of Reward: 0.0308459709347.
# Step: 4370000. Mean Reward: 2.99405893536. Std of Reward: 0.141372174008.
# Step: 4380000. Mean Reward: 3.0. Std of Reward: 0.0.
# Step: 4390000. Mean Reward: 3.0. Std of Reward: 0.0.
# Step: 4400000. Mean Reward: 2.99619410086. Std of Reward: 0.123325227372.
# Saved Model
# Step: 4410000. Mean Reward: 2.99195075758. Std of Reward: 0.152493732607.
# Step: 4420000. Mean Reward: 3.0. Std of Reward: 0.0.
# Step: 4430000. Mean Reward: 2.99455492424. Std of Reward: 0.103358337095.
# Step: 4440000. Mean Reward: 2.99619771863. Std of Reward: 0.108938844927.
# Step: 4450000. Mean Reward: 2.99952426261. Std of Reward: 0.0154156534215.
# Saved Model
# Step: 4460000. Mean Reward: 2.99619771863. Std of Reward: 0.123266654581.
# Step: 4470000. Mean Reward: 2.99619771863. Std of Reward: 0.09495241391.
# Step: 4480000. Mean Reward: 3.0. Std of Reward: 0.0.
# Step: 4490000. Mean Reward: 3.0. Std of Reward: 0.0.
# Step: 4500000. Mean Reward: 2.99952516619. Std of Reward: 0.015401020646.
# Saved Model
# Step: 4510000. Mean Reward: 2.99691358025. Std of Reward: 0.100106634199.
# Step: 4520000. Mean Reward: 2.99620132953. Std of Reward: 0.0973768261243.
# Step: 4530000. Mean Reward: 2.99905033238. Std of Reward: 0.030802041292.
# Step: 4540000. Mean Reward: 2.99596391263. Std of Reward: 0.0926826454725.
# Step: 4550000. Mean Reward: 2.99146919431. Std of Reward: 0.160119098887.
# Saved Model
# Step: 4560000. Mean Reward: 2.99691943128. Std of Reward: 0.100011791493.
# Step: 4570000. Mean Reward: 2.99786527514. Std of Reward: 0.0692717394005.
# Step: 4580000. Mean Reward: 2.99691064639. Std of Reward: 0.100154156847.
# Step: 4590000. Mean Reward: 3.0. Std of Reward: 0.0.
# Step: 4600000. Mean Reward: 2.99122390892. Std of Reward: 0.168657274496.
# Saved Model
# Step: 4610000. Mean Reward: 2.99524262607. Std of Reward: 0.113235493566.
# Step: 4620000. Mean Reward: 2.99572649573. Std of Reward: 0.112092966227.
# Step: 4630000. Mean Reward: 3.0. Std of Reward: 0.0.
# Step: 4640000. Mean Reward: 2.99146919431. Std of Reward: 0.176654595772.
# Step: 4650000. Mean Reward: 2.99691064639. Std of Reward: 0.100154156847.
# Saved Model
# Step: 4660000. Mean Reward: 2.99667931689. Std of Reward: 0.107756039067.
# Step: 4670000. Mean Reward: 2.99596007605. Std of Reward: 0.104759957026.
# Step: 4680000. Mean Reward: 3.0. Std of Reward: 0.0.
# Step: 4690000. Mean Reward: 2.99666983825. Std of Reward: 0.107909573951.
# Step: 4700000. Mean Reward: 2.99714557564. Std of Reward: 0.0924939205291.
# Saved Model
# Step: 4710000. Mean Reward: 2.99146919431. Std of Reward: 0.167000930124.
# Step: 4720000. Mean Reward: 2.99667931689. Std of Reward: 0.107756039067.
# Step: 4730000. Mean Reward: 2.99621212121. Std of Reward: 0.123033195219.
# Step: 4740000. Mean Reward: 2.99315391879. Std of Reward: 0.158226913925.
# Step: 4750000. Mean Reward: 2.99809705043. Std of Reward: 0.0616626136861.
# Saved Model
# Step: 4760000. Mean Reward: 2.99952471483. Std of Reward: 0.0154083318227.
# Step: 4770000. Mean Reward: 2.99904852521. Std of Reward: 0.030831306843.
# Step: 4780000. Mean Reward: 3.0. Std of Reward: 0.0.
# Step: 4790000. Mean Reward: 2.9969047619. Std of Reward: 0.100249405538.
# Step: 4800000. Mean Reward: 2.9990512334. Std of Reward: 0.0307874397336.
# Saved Model
# Step: 4810000. Mean Reward: 2.99761904762. Std of Reward: 0.0555838929997.
# Step: 4820000. Mean Reward: 2.99621212121. Std of Reward: 0.0972386185833.
# Step: 4830000. Mean Reward: 2.99383301708. Std of Reward: 0.12544007774.
# Step: 4840000. Mean Reward: 2.99714828897. Std of Reward: 0.092449990936.
# Step: 4850000. Mean Reward: 2.99573863636. Std of Reward: 0.123976200763.
# Saved Model
# Step: 4860000. Mean Reward: 2.99523809524. Std of Reward: 0.127152665932.
# Step: 4870000. Mean Reward: 3.0. Std of Reward: 0.0.
# Step: 4880000. Mean Reward: 3.0. Std of Reward: 0.0.
# Step: 4890000. Mean Reward: 3.0. Std of Reward: 0.0.
# Step: 4900000. Mean Reward: 2.99715099715. Std of Reward: 0.0924061238759.
# Saved Model
# Step: 4910000. Mean Reward: 2.99526515152. Std of Reward: 0.110852096374.
# Step: 4920000. Mean Reward: 3.0. Std of Reward: 0.0.
# Step: 4930000. Mean Reward: 2.99405328259. Std of Reward: 0.136300631149.
# Step: 4940000. Mean Reward: 2.99242424242. Std of Reward: 0.173912731564.
# Step: 4950000. Mean Reward: 3.0. Std of Reward: 0.0.
# Saved Model
# Step: 4960000. Mean Reward: 3.0. Std of Reward: 0.0.
# Step: 4970000. Mean Reward: 3.0. Std of Reward: 0.0.
# Step: 4980000. Mean Reward: 2.99786324786. Std of Reward: 0.069304592907.
# Step: 4990000. Mean Reward: 3.0. Std of Reward: 0.0.
# Step: 5000000. Mean Reward: 2.9990512334. Std of Reward: 0.0307874397336.
# Saved Model
# Step: 5010000. Mean Reward: 3.0. Std of Reward: 0.0.
# Step: 5020000. Mean Reward: 3.0. Std of Reward: 0.0.
# Step: 5030000. Mean Reward: 3.0. Std of Reward: 0.0.
# Step: 5040000. Mean Reward: 3.0. Std of Reward: 0.0.
# Step: 5050000. Mean Reward: 3.0. Std of Reward: 0.0.
# Saved Model
# Step: 5060000. Mean Reward: 2.99810964083. Std of Reward: 0.0614584809339.
# Step: 5070000. Mean Reward: 3.0. Std of Reward: 0.0.
# Step: 5080000. Mean Reward: 3.0. Std of Reward: 0.0.
# Step: 5090000. Mean Reward: 2.99785714286. Std of Reward: 0.069403434603.
# Step: 5100000. Mean Reward: 3.0. Std of Reward: 0.0.
# Saved Model
# Step: 5110000. Mean Reward: 3.0. Std of Reward: 0.0.
# Step: 5120000. Mean Reward: 3.0. Std of Reward: 0.0.
# Step: 5130000. Mean Reward: 2.99905033238. Std of Reward: 0.030802041292.
# Step: 5140000. Mean Reward: 2.9990530303. Std of Reward: 0.0217390914455.
# Step: 5150000. Mean Reward: 2.99288425047. Std of Reward: 0.163560455658.
# Saved Model
# Step: 5160000. Mean Reward: 3.0. Std of Reward: 0.0.
# Step: 5170000. Mean Reward: 2.99904852521. Std of Reward: 0.030831306843.
# Step: 5180000. Mean Reward: 3.0. Std of Reward: 0.0.
# Step: 5190000. Mean Reward: 2.99857685009. Std of Reward: 0.0461811596003.
# Step: 5200000. Mean Reward: 2.99810066477. Std of Reward: 0.0435399558836.
# Saved Model
# Step: 5210000. Mean Reward: 2.99810066477. Std of Reward: 0.061604082584.
# Step: 5220000. Mean Reward: 2.99429115128. Std of Reward: 0.115273830721.
# Step: 5230000. Mean Reward: 2.99217267552. Std of Reward: 0.161521244727.
# Step: 5240000. Mean Reward: 2.99952471483. Std of Reward: 0.0154083318227.
# Step: 5250000. Mean Reward: 2.99715370019. Std of Reward: 0.0923623192007.
# Saved Model
# Step: 5260000. Mean Reward: 3.0. Std of Reward: 0.0.
# Step: 5270000. Mean Reward: 3.0. Std of Reward: 0.0.
# Step: 5280000. Mean Reward: 2.9990512334. Std of Reward: 0.0307874397336.
# Step: 5290000. Mean Reward: 2.99810606061. Std of Reward: 0.0615165976095.
# Step: 5300000. Mean Reward: 3.0. Std of Reward: 0.0.
# Saved Model
# Step: 5310000. Mean Reward: 2.99857414449. Std of Reward: 0.0344409620047.
# Step: 5320000. Mean Reward: 3.0. Std of Reward: 0.0.
# Step: 5330000. Mean Reward: 2.99857549858. Std of Reward: 0.046203061938.
# Step: 5340000. Mean Reward: 3.0. Std of Reward: 0.0.
# Step: 5350000. Mean Reward: 2.9966730038. Std of Reward: 0.0937107611841.
# Saved Model
# Step: 5360000. Mean Reward: 2.993140965. Std of Reward: 0.158376257013.
# Step: 5370000. Mean Reward: 2.99810246679. Std of Reward: 0.0486653457428.
# Step: 5380000. Mean Reward: 2.99905033238. Std of Reward: 0.030802041292.
# Step: 5390000. Mean Reward: 3.0. Std of Reward: 0.0.
# Step: 5400000. Mean Reward: 3.0. Std of Reward: 0.0.
# Saved Model
# Step: 5410000. Mean Reward: 3.0. Std of Reward: 0.0.
# Step: 5420000. Mean Reward: 2.99691650854. Std of Reward: 0.100059179134.
# Step: 5430000. Mean Reward: 2.99621212121. Std of Reward: 0.0783642457029.
# Step: 5440000. Mean Reward: 3.0. Std of Reward: 0.0.
# Step: 5450000. Mean Reward: 3.0. Std of Reward: 0.0.
# Saved Model
# Step: 5460000. Mean Reward: 3.0. Std of Reward: 0.0.
# Step: 5470000. Mean Reward: 2.99714285714. Std of Reward: 0.0689473820866.
# Step: 5480000. Mean Reward: 2.99620132953. Std of Reward: 0.123208165168.
# Step: 5490000. Mean Reward: 3.0. Std of Reward: 0.0.
# Step: 5500000. Mean Reward: 2.99383301708. Std of Reward: 0.1259119094.
# Saved Model
# Step: 5510000. Mean Reward: 2.99810246679. Std of Reward: 0.0615748794671.
# Step: 5520000. Mean Reward: 3.0. Std of Reward: 0.0.
# Step: 5530000. Mean Reward: 3.0. Std of Reward: 0.0.
# Step: 5540000. Mean Reward: 2.99952516619. Std of Reward: 0.015401020646.
# Step: 5550000. Mean Reward: 2.9980952381. Std of Reward: 0.0616919418693.
# Saved Model
# Step: 5560000. Mean Reward: 2.99857278782. Std of Reward: 0.0462469602646.
# Step: 5570000. Mean Reward: 3.0. Std of Reward: 0.0.
# Step: 5580000. Mean Reward: 3.0. Std of Reward: 0.0.
# Step: 5590000. Mean Reward: 2.99619410086. Std of Reward: 0.123325227372.
# Step: 5600000. Mean Reward: 2.99241706161. Std of Reward: 0.173994978663.
# Saved Model
# Step: 5610000. Mean Reward: 3.0. Std of Reward: 0.0.
# Step: 5620000. Mean Reward: 2.99573459716. Std of Reward: 0.124034873888.
# Step: 5630000. Mean Reward: 2.99905033238. Std of Reward: 0.030802041292.
# Step: 5640000. Mean Reward: 2.99098671727. Std of Reward: 0.180038931627.
# Step: 5650000. Mean Reward: 3.0. Std of Reward: 0.0.
# Saved Model
# Step: 5660000. Mean Reward: 2.99667616334. Std of Reward: 0.107807144522.
# Step: 5670000. Mean Reward: 2.99905033238. Std of Reward: 0.030802041292.
# Step: 5680000. Mean Reward: 2.99621212121. Std of Reward: 0.123033195219.
# Step: 5690000. Mean Reward: 2.9943019943. Std of Reward: 0.137698529614.
# Step: 5700000. Mean Reward: 3.0. Std of Reward: 0.0.
# Saved Model
# Step: 5710000. Mean Reward: 3.0. Std of Reward: 0.0.
# Step: 5720000. Mean Reward: 2.99572649573. Std of Reward: 0.0985689110656.
# Step: 5730000. Mean Reward: 2.99904942966. Std of Reward: 0.0308166636453.
# Step: 5740000. Mean Reward: 2.9995256167. Std of Reward: 0.0153937198668.
# Step: 5750000. Mean Reward: 2.99857142857. Std of Reward: 0.046268956402.
# Saved Model
# Step: 5760000. Mean Reward: 3.0. Std of Reward: 0.0.
# Step: 5770000. Mean Reward: 2.99335232669. Std of Reward: 0.126886397684.
# Step: 5780000. Mean Reward: 2.99335232669. Std of Reward: 0.153939919605.
# Step: 5790000. Mean Reward: 3.0. Std of Reward: 0.0.
# Step: 5800000. Mean Reward: 2.9981042654. Std of Reward: 0.0615457178417.
# Saved Model
# Step: 5810000. Mean Reward: 3.0. Std of Reward: 0.0.
# Step: 5820000. Mean Reward: 2.9990521327. Std of Reward: 0.0307728589208.
# Step: 5830000. Mean Reward: 2.99809885932. Std of Reward: 0.0435606054654.
# Step: 5840000. Mean Reward: 3.0. Std of Reward: 0.0.
# Step: 5850000. Mean Reward: 2.99240265907. Std of Reward: 0.156951070195.
# Saved Model
# Step: 5860000. Mean Reward: 2.99905033238. Std of Reward: 0.030802041292.
# Step: 5870000. Mean Reward: 3.0. Std of Reward: 0.0.
# Step: 5880000. Mean Reward: 3.0. Std of Reward: 0.0.
# Step: 5890000. Mean Reward: 3.0. Std of Reward: 0.0.
# Step: 5900000. Mean Reward: 2.99857819905. Std of Reward: 0.0343920427612.
# Saved Model
# Step: 5910000. Mean Reward: 2.99714828897. Std of Reward: 0.0576095820323.
# Step: 5920000. Mean Reward: 2.99666983825. Std of Reward: 0.107909573951.
# Step: 5930000. Mean Reward: 2.99952516619. Std of Reward: 0.015401020646.
# Step: 5940000. Mean Reward: 3.0. Std of Reward: 0.0.
# Step: 5950000. Mean Reward: 2.99809705043. Std of Reward: 0.0616626136861.
# Saved Model
# Step: 5960000. Mean Reward: 2.99596007605. Std of Reward: 0.104759957026.
# Step: 5970000. Mean Reward: 3.0. Std of Reward: 0.0.
# Step: 5980000. Mean Reward: 2.99714828897. Std of Reward: 0.092449990936.
# Step: 5990000. Mean Reward: 3.0. Std of Reward: 0.0.
# Step: 6000000. Mean Reward: 3.0. Std of Reward: 0.0.
# Saved Model
# Step: 6010000. Mean Reward: 2.99881291548. Std of Reward: 0.038502551615.
# Step: 6020000. Mean Reward: 2.99858088931. Std of Reward: 0.0461156390046.
# Step: 6030000. Mean Reward: 3.0. Std of Reward: 0.0.
# Step: 6040000. Mean Reward: 2.99904852521. Std of Reward: 0.030831306843.
# Step: 6050000. Mean Reward: 2.99762583096. Std of Reward: 0.0770051032299.
# Saved Model
# Step: 6060000. Mean Reward: 3.0. Std of Reward: 0.0.
# Step: 6070000. Mean Reward: 2.99905033238. Std of Reward: 0.030802041292.
# Step: 6080000. Mean Reward: 2.99691358025. Std of Reward: 0.100106634199.
# Step: 6090000. Mean Reward: 2.99288425047. Std of Reward: 0.148351574438.
# Step: 6100000. Mean Reward: 3.0. Std of Reward: 0.0.
# Saved Model
# Step: 6110000. Mean Reward: 2.9990512334. Std of Reward: 0.0307874397336.
# Step: 6120000. Mean Reward: 3.0. Std of Reward: 0.0.
# Step: 6130000. Mean Reward: 2.99287749288. Std of Reward: 0.163637954197.
# Step: 6140000. Mean Reward: 2.99667616334. Std of Reward: 0.107807144522.
# Step: 6150000. Mean Reward: 2.99809885932. Std of Reward: 0.0435606054654.
# Saved Model
# Step: 6160000. Mean Reward: 2.99668560606. Std of Reward: 0.107654045817.
# Step: 6170000. Mean Reward: 2.99620132953. Std of Reward: 0.123208165168.
# Step: 6180000. Mean Reward: 2.9990512334. Std of Reward: 0.0307874397336.
# Step: 6190000. Mean Reward: 2.9990512334. Std of Reward: 0.0307874397336.
# Step: 6200000. Mean Reward: 3.0. Std of Reward: 0.0.
# Saved Model
# Step: 6210000. Mean Reward: 3.0. Std of Reward: 0.0.
# Step: 6220000. Mean Reward: 3.0. Std of Reward: 0.0.
# Step: 6230000. Mean Reward: 3.0. Std of Reward: 0.0.
# Step: 6240000. Mean Reward: 3.0. Std of Reward: 0.0.
# Step: 6250000. Mean Reward: 3.0. Std of Reward: 0.0.
# Saved Model
# Step: 6260000. Mean Reward: 2.99620132953. Std of Reward: 0.108887167779.
# Step: 6270000. Mean Reward: 3.0. Std of Reward: 0.0.
# Step: 6280000. Mean Reward: 2.99715099715. Std of Reward: 0.0924061238759.
# Step: 6290000. Mean Reward: 3.0. Std of Reward: 0.0.
# Step: 6300000. Mean Reward: 3.0. Std of Reward: 0.0.
# Saved Model
# Step: 6310000. Mean Reward: 3.0. Std of Reward: 0.0.
# Step: 6320000. Mean Reward: 2.9990512334. Std of Reward: 0.0307874397336.
# Step: 6330000. Mean Reward: 2.99904852521. Std of Reward: 0.030831306843.
# Step: 6340000. Mean Reward: 3.0. Std of Reward: 0.0.
# Step: 6350000. Mean Reward: 2.99476688868. Std of Reward: 0.131670153751.
# Saved Model
# Step: 6360000. Mean Reward: 2.99144486692. Std of Reward: 0.164371726434.
# Step: 6370000. Mean Reward: 2.99005681818. Std of Reward: 0.186285451657.
# Step: 6380000. Mean Reward: 2.99762131304. Std of Reward: 0.0770782671076.
# Step: 6390000. Mean Reward: 2.99667931689. Std of Reward: 0.107756039067.
# Step: 6400000. Mean Reward: 3.0. Std of Reward: 0.0.
# Saved Model
# Step: 6410000. Mean Reward: 3.0. Std of Reward: 0.0.
# Step: 6420000. Mean Reward: 2.99288425047. Std of Reward: 0.163560455658.
# Step: 6430000. Mean Reward: 3.0. Std of Reward: 0.0.
# Step: 6440000. Mean Reward: 2.99904942966. Std of Reward: 0.0308166636453.
# Step: 6450000. Mean Reward: 2.99691064639. Std of Reward: 0.100154156847.
# Saved Model
# Step: 6460000. Mean Reward: 2.99335232669. Std of Reward: 0.152389845592.
# Step: 6470000. Mean Reward: 3.0. Std of Reward: 0.0.
# Step: 6480000. Mean Reward: 2.99407582938. Std of Reward: 0.13604248686.
# Step: 6490000. Mean Reward: 3.0. Std of Reward: 0.0.
# Step: 6500000. Mean Reward: 2.99810066477. Std of Reward: 0.061604082584.
# Saved Model
# Step: 6510000. Mean Reward: 2.99952426261. Std of Reward: 0.0154156534215.
# Step: 6520000. Mean Reward: 2.99952380952. Std of Reward: 0.0154229854673.
# Step: 6530000. Mean Reward: 2.99857549858. Std of Reward: 0.046203061938.
# Step: 6540000. Mean Reward: 2.99952426261. Std of Reward: 0.0154156534215.
# ...
# Step: 7630000. Mean Reward: 3.0. Std of Reward: 0.0.
# Step: 7640000. Mean Reward: 2.99810246679. Std of Reward: 0.0615748794671.
# Step: 7650000. Mean Reward: 3.0. Std of Reward: 0.0.
# Saved Model
# Step: 7660000. Mean Reward: 2.99454976303. Std of Reward: 0.126120235785.
# Step: 7670000. Mean Reward: 3.0. Std of Reward: 0.0.
# Step: 7680000. Mean Reward: 3.0. Std of Reward: 0.0.
# Step: 7690000. Mean Reward: 3.0. Std of Reward: 0.0.
# Step: 7700000. Mean Reward: 2.99620132953. Std of Reward: 0.123208165168.
# Saved Model
# Step: 7710000. Mean Reward: 2.99596774194. Std of Reward: 0.104660664755.
# Step: 7720000. Mean Reward: 2.99312796209. Std of Reward: 0.158526023773.
# Step: 7730000. Mean Reward: 2.99691064639. Std of Reward: 0.0758504356868.
# Step: 7740000. Mean Reward: 2.9971563981. Std of Reward: 0.0923185767625.
# Step: 7750000. Mean Reward: 2.99360189573. Std of Reward: 0.146909111394.
# Saved Model
# Step: 7760000. Mean Reward: 3.0. Std of Reward: 0.0.
# Step: 7770000. Mean Reward: 2.99857685009. Std of Reward: 0.0344083260072.
# Step: 7780000. Mean Reward: 2.99952426261. Std of Reward: 0.0154156534215.
# Step: 7790000. Mean Reward: 2.99382716049. Std of Reward: 0.125499482764.
# Step: 7800000. Mean Reward: 3.0. Std of Reward: 0.0.
# Saved Model
# Step: 7810000. Mean Reward: 3.0. Std of Reward: 0.0.
# Step: 7820000. Mean Reward: 2.99573055028. Std of Reward: 0.11203985583.
# Step: 7830000. Mean Reward: 3.0. Std of Reward: 0.0.
# Step: 7840000. Mean Reward: 2.9990512334. Std of Reward: 0.0307874397336.
# Step: 7850000. Mean Reward: 3.0. Std of Reward: 0.0.
# Saved Model
# Step: 7860000. Mean Reward: 3.0. Std of Reward: 0.0.
# Step: 7870000. Mean Reward: 3.0. Std of Reward: 0.0.
# Step: 7880000. Mean Reward: 2.99952426261. Std of Reward: 0.0154156534215.
# Step: 7890000. Mean Reward: 2.9990521327. Std of Reward: 0.0307728589208.
# Step: 7900000. Mean Reward: 2.99572649573. Std of Reward: 0.10327389721.
# Saved Model
# Step: 7910000. Mean Reward: 2.99526963103. Std of Reward: 0.0921536095507.
# Step: 7920000. Mean Reward: 2.99288425047. Std of Reward: 0.163560455658.
# Step: 7930000. Mean Reward: 2.99551039698. Std of Reward: 0.109954340006.
# Step: 7940000. Mean Reward: 2.99904852521. Std of Reward: 0.030831306843.
# Step: 7950000. Mean Reward: 3.0. Std of Reward: 0.0.
# Saved Model
# Step: 7960000. Mean Reward: 3.0. Std of Reward: 0.0.
# Step: 7970000. Mean Reward: 2.99905033238. Std of Reward: 0.030802041292.
# Step: 7980000. Mean Reward: 3.0. Std of Reward: 0.0.
# Step: 7990000. Mean Reward: 2.99690770695. Std of Reward: 0.10020174724.
# Step: 8000000. Mean Reward: 3.0. Std of Reward: 0.0.
# Saved Model
# Step: 8010000. Mean Reward: 2.99667931689. Std of Reward: 0.107756039067.
# Step: 8020000. Mean Reward: 2.99952516619. Std of Reward: 0.015401020646.
# Step: 8030000. Mean Reward: 3.0. Std of Reward: 0.0.
# Step: 8040000. Mean Reward: 3.0. Std of Reward: 0.0.
# Step: 8050000. Mean Reward: 2.9990512334. Std of Reward: 0.0307874397336.
# Saved Model
# Step: 8060000. Mean Reward: 2.99904852521. Std of Reward: 0.030831306843.
# Step: 8070000. Mean Reward: 3.0. Std of Reward: 0.0.
# Step: 8080000. Mean Reward: 2.99123222749. Std of Reward: 0.153108077877.
# Step: 8090000. Mean Reward: 3.0. Std of Reward: 0.0.
# Step: 8100000. Mean Reward: 2.99691943128. Std of Reward: 0.100011791493.
# Saved Model
# Step: 8110000. Mean Reward: 2.99810066477. Std of Reward: 0.061604082584.
# Step: 8120000. Mean Reward: 3.0. Std of Reward: 0.0.
# Step: 8130000. Mean Reward: 3.0. Std of Reward: 0.0.
# Step: 8140000. Mean Reward: 3.0. Std of Reward: 0.0.
# Step: 8150000. Mean Reward: 2.99714557564. Std of Reward: 0.0689146297326.
# Saved Model
# Step: 8160000. Mean Reward: 3.0. Std of Reward: 0.0.
# Step: 8170000. Mean Reward: 2.99762808349. Std of Reward: 0.0769685993339.
# Step: 8180000. Mean Reward: 3.0. Std of Reward: 0.0.
# Step: 8190000. Mean Reward: 3.0. Std of Reward: 0.0.
# Step: 8200000. Mean Reward: 3.0. Std of Reward: 0.0.
# Saved Model
# Step: 8210000. Mean Reward: 2.99857142857. Std of Reward: 0.046268956402.
# Step: 8220000. Mean Reward: 3.0. Std of Reward: 0.0.
# Step: 8230000. Mean Reward: 3.0. Std of Reward: 0.0.
# Step: 8240000. Mean Reward: 3.0. Std of Reward: 0.0.
# Step: 8250000. Mean Reward: 3.0. Std of Reward: 0.0.
# Saved Model
# Step: 8260000. Mean Reward: 3.0. Std of Reward: 0.0.
# Step: 8270000. Mean Reward: 2.99785918173. Std of Reward: 0.0693704403968.
# Step: 8280000. Mean Reward: 2.99620132953. Std of Reward: 0.123208165168.
# Step: 8290000. Mean Reward: 2.99691064639. Std of Reward: 0.100154156847.
# Step: 8300000. Mean Reward: 2.99667616334. Std of Reward: 0.107807144522.
# Saved Model
# Step: 8310000. Mean Reward: 3.0. Std of Reward: 0.0.
# Step: 8320000. Mean Reward: 3.0. Std of Reward: 0.0.
# Step: 8330000. Mean Reward: 3.0. Std of Reward: 0.0.
# Step: 8340000. Mean Reward: 2.99620853081. Std of Reward: 0.123091435683.
# Step: 8350000. Mean Reward: 3.0. Std of Reward: 0.0.
# Saved Model
# Step: 8360000. Mean Reward: 3.0. Std of Reward: 0.0.
# Step: 8370000. Mean Reward: 2.99619410086. Std of Reward: 0.123325227372.
# Step: 8380000. Mean Reward: 2.99715370019. Std of Reward: 0.0923623192007.
# Step: 8390000. Mean Reward: 2.99809885932. Std of Reward: 0.0616333272907.
# Step: 8400000. Mean Reward: 3.0. Std of Reward: 0.0.
# Saved Model
# Step: 8410000. Mean Reward: 2.99691358025. Std of Reward: 0.100106634199.
# Step: 8420000. Mean Reward: 3.0. Std of Reward: 0.0.
# Step: 8430000. Mean Reward: 2.99810066477. Std of Reward: 0.061604082584.
# Step: 8440000. Mean Reward: 2.99690181125. Std of Reward: 0.100297131902.
# Step: 8450000. Mean Reward: 3.0. Std of Reward: 0.0.
# Saved Model
# Step: 8460000. Mean Reward: 2.99833808167. Std of Reward: 0.053903572261.
# Step: 8470000. Mean Reward: 2.99857142857. Std of Reward: 0.046268956402.
# Step: 8480000. Mean Reward: 3.0. Std of Reward: 0.0.
# Step: 8490000. Mean Reward: 2.99714557564. Std of Reward: 0.0924939205291.
# Step: 8500000. Mean Reward: 2.99169829222. Std of Reward: 0.165128493631.
# Saved Model
# Step: 8510000. Mean Reward: 2.99786527514. Std of Reward: 0.0692717394005.
# Step: 8520000. Mean Reward: 3.0. Std of Reward: 0.0.
# Step: 8530000. Mean Reward: 3.0. Std of Reward: 0.0.
# Step: 8540000. Mean Reward: 3.0. Std of Reward: 0.0.
# Step: 8550000. Mean Reward: 2.99762808349. Std of Reward: 0.0554785136172.
# Saved Model
# Step: 8560000. Mean Reward: 2.9971563981. Std of Reward: 0.0923185767625.
# Step: 8570000. Mean Reward: 3.0. Std of Reward: 0.0.
# Step: 8580000. Mean Reward: 3.0. Std of Reward: 0.0.
# Step: 8590000. Mean Reward: 2.99810246679. Std of Reward: 0.0435193356402.
# Step: 8600000. Mean Reward: 3.0. Std of Reward: 0.0.
# Saved Model
# Step: 8610000. Mean Reward: 2.99904852521. Std of Reward: 0.030831306843.
# Step: 8620000. Mean Reward: 2.99810246679. Std of Reward: 0.0615748794671.
# Step: 8630000. Mean Reward: 2.99120722433. Std of Reward: 0.153325515528.
# Step: 8640000. Mean Reward: 2.99526066351. Std of Reward: 0.126851420037.
# Step: 8650000. Mean Reward: 3.0. Std of Reward: 0.0.
# Saved Model
# Step: 8660000. Mean Reward: 3.0. Std of Reward: 0.0.
# Step: 8670000. Mean Reward: 3.0. Std of Reward: 0.0.
# Step: 8680000. Mean Reward: 3.0. Std of Reward: 0.0.
# Step: 8690000. Mean Reward: 2.99809705043. Std of Reward: 0.0487346462768.
# Step: 8700000. Mean Reward: 2.99525616698. Std of Reward: 0.117194760113.
# Saved Model
# Step: 8710000. Mean Reward: 3.0. Std of Reward: 0.0.
# Step: 8720000. Mean Reward: 3.0. Std of Reward: 0.0.
# Step: 8730000. Mean Reward: 3.0. Std of Reward: 0.0.
# Step: 8740000. Mean Reward: 2.99004739336. Std of Reward: 0.187640620584.
# Step: 8750000. Mean Reward: 2.99833808167. Std of Reward: 0.053903572261.
# Saved Model
# Step: 8760000. Mean Reward: 2.99691358025. Std of Reward: 0.100106634199.
# Step: 8770000. Mean Reward: 2.99526066351. Std of Reward: 0.126851420037.
# Step: 8780000. Mean Reward: 2.99359582543. Std of Reward: 0.146978653853.
# Step: 8790000. Mean Reward: 2.99714828897. Std of Reward: 0.092449990936.
# Step: 8800000. Mean Reward: 2.99786121673. Std of Reward: 0.069337493202.
# Saved Model
# Step: 8810000. Mean Reward: 3.0. Std of Reward: 0.0.
# Step: 8820000. Mean Reward: 2.99857142857. Std of Reward: 0.046268956402.
# Step: 8830000. Mean Reward: 3.0. Std of Reward: 0.0.
# Step: 8840000. Mean Reward: 2.99833333333. Std of Reward: 0.0539804491357.
# Step: 8850000. Mean Reward: 2.99527410208. Std of Reward: 0.126671696992.
# Saved Model
# Step: 8860000. Mean Reward: 2.99715099715. Std of Reward: 0.0924061238759.
# Step: 8870000. Mean Reward: 3.0. Std of Reward: 0.0.
# Step: 8880000. Mean Reward: 3.0. Std of Reward: 0.0.
# Step: 8890000. Mean Reward: 3.0. Std of Reward: 0.0.
# Step: 8900000. Mean Reward: 2.99289772727. Std of Reward: 0.163405788335.
# Saved Model
# Step: 8910000. Mean Reward: 3.0. Std of Reward: 0.0.
# Step: 8920000. Mean Reward: 2.99430740038. Std of Reward: 0.137633304029.
# Step: 8930000. Mean Reward: 2.9966730038. Std of Reward: 0.107858322759.
# Step: 8940000. Mean Reward: 2.99525616698. Std of Reward: 0.117194760113.
# Step: 8950000. Mean Reward: 3.0. Std of Reward: 0.0.
# Saved Model
# Step: 8960000. Mean Reward: 2.99856870229. Std of Reward: 0.0463130429982.
# Step: 8970000. Mean Reward: 3.0. Std of Reward: 0.0.
# Step: 8980000. Mean Reward: 3.0. Std of Reward: 0.0.
# Step: 8990000. Mean Reward: 2.99762808349. Std of Reward: 0.0554785136172.
# Step: 9000000. Mean Reward: 3.0. Std of Reward: 0.0.
# Saved Model
# Step: 9010000. Mean Reward: 2.99358974359. Std of Reward: 0.147048295163.
# Step: 9020000. Mean Reward: 2.99667616334. Std of Reward: 0.0829098445801.
# Step: 9030000. Mean Reward: 2.99524714829. Std of Reward: 0.111062256637.
# Step: 9040000. Mean Reward: 2.9990521327. Std of Reward: 0.0307728589208.
# Step: 9050000. Mean Reward: 3.0. Std of Reward: 0.0.
# Saved Model
# Step: 9060000. Mean Reward: 2.99692234848. Std of Reward: 0.0999644711155.
# Step: 9070000. Mean Reward: 3.0. Std of Reward: 0.0.
# Step: 9080000. Mean Reward: 2.99524714829. Std of Reward: 0.127031910236.
# Step: 9090000. Mean Reward: 3.0. Std of Reward: 0.0.
# Step: 9100000. Mean Reward: 3.0. Std of Reward: 0.0.
# Saved Model
# Step: 9110000. Mean Reward: 3.0. Std of Reward: 0.0.
# Step: 9120000. Mean Reward: 2.99715909091. Std of Reward: 0.0922748964143.
# Step: 9130000. Mean Reward: 3.0. Std of Reward: 0.0.
# Step: 9140000. Mean Reward: 2.99810246679. Std of Reward: 0.0615748794671.
# Step: 9150000. Mean Reward: 2.9995256167. Std of Reward: 0.0153937198668.
# Saved Model
# Step: 9160000. Mean Reward: 3.0. Std of Reward: 0.0.
# Step: 9170000. Mean Reward: 3.0. Std of Reward: 0.0.
# Step: 9180000. Mean Reward: 3.0. Std of Reward: 0.0.
# Step: 9190000. Mean Reward: 2.99382716049. Std of Reward: 0.141923686887.
# Step: 9200000. Mean Reward: 3.0. Std of Reward: 0.0.
# Saved Model
# Step: 9210000. Mean Reward: 2.99572243346. Std of Reward: 0.112146152224.
# Step: 9220000. Mean Reward: 3.0. Std of Reward: 0.0.
# Step: 9230000. Mean Reward: 2.99714828897. Std of Reward: 0.092449990936.
# Step: 9240000. Mean Reward: 3.0. Std of Reward: 0.0.
# Step: 9250000. Mean Reward: 3.0. Std of Reward: 0.0.
# Saved Model
# Step: 9260000. Mean Reward: 2.99857414449. Std of Reward: 0.046224995468.
# Step: 9270000. Mean Reward: 2.99904852521. Std of Reward: 0.030831306843.
# Step: 9280000. Mean Reward: 3.0. Std of Reward: 0.0.
# Step: 9290000. Mean Reward: 3.0. Std of Reward: 0.0.
# Step: 9300000. Mean Reward: 2.99904942966. Std of Reward: 0.0308166636453.
# Saved Model
# Step: 9310000. Mean Reward: 3.0. Std of Reward: 0.0.
# Step: 9320000. Mean Reward: 3.0. Std of Reward: 0.0.
# Step: 9330000. Mean Reward: 2.9981042654. Std of Reward: 0.0615457178417.
# Step: 9340000. Mean Reward: 3.0. Std of Reward: 0.0.
# Step: 9350000. Mean Reward: 3.0. Std of Reward: 0.0.
# Saved Model
# Step: 9360000. Mean Reward: 3.0. Std of Reward: 0.0.
# Step: 9370000. Mean Reward: 3.0. Std of Reward: 0.0.
# Step: 9380000. Mean Reward: 3.0. Std of Reward: 0.0.
# Step: 9390000. Mean Reward: 3.0. Std of Reward: 0.0.
# Step: 9400000. Mean Reward: 3.0. Std of Reward: 0.0.
# Saved Model
# Step: 9410000. Mean Reward: 3.0. Std of Reward: 0.0.
# Step: 9420000. Mean Reward: 3.0. Std of Reward: 0.0.
# Step: 9430000. Mean Reward: 2.99810246679. Std of Reward: 0.0615748794671.
# Step: 9440000. Mean Reward: 2.99524714829. Std of Reward: 0.0923717677673.
# Step: 9450000. Mean Reward: 2.99619771863. Std of Reward: 0.123266654581.
# Saved Model
# Step: 9460000. Mean Reward: 2.99691358025. Std of Reward: 0.100106634199.
# Step: 9470000. Mean Reward: 2.99571836346. Std of Reward: 0.112199414.
# Step: 9480000. Mean Reward: 2.99621212121. Std of Reward: 0.0869563657822.
# Step: 9490000. Mean Reward: 2.99809885932. Std of Reward: 0.0616333272907.
# Step: 9500000. Mean Reward: 2.99714013346. Std of Reward: 0.0925819679098.
# Saved Model
# Step: 9510000. Mean Reward: 2.99952471483. Std of Reward: 0.0154083318227.
# Step: 9520000. Mean Reward: 3.0. Std of Reward: 0.0.
# Step: 9530000. Mean Reward: 3.0. Std of Reward: 0.0.
# Step: 9540000. Mean Reward: 3.0. Std of Reward: 0.0.
# Step: 9550000. Mean Reward: 2.99620132953. Std of Reward: 0.0973768261243.
# Saved Model
# Step: 9560000. Mean Reward: 3.0. Std of Reward: 0.0.
# Step: 9570000. Mean Reward: 3.0. Std of Reward: 0.0.
# Step: 9580000. Mean Reward: 2.9971563981. Std of Reward: 0.0923185767625.
# Step: 9590000. Mean Reward: 2.99904942966. Std of Reward: 0.0308166636453.
# Step: 9600000. Mean Reward: 3.0. Std of Reward: 0.0.
# Saved Model
# Step: 9610000. Mean Reward: 2.99383886256. Std of Reward: 0.141789352492.
# Step: 9620000. Mean Reward: 2.99714828897. Std of Reward: 0.092449990936.
# Step: 9630000. Mean Reward: 2.9983365019. Std of Reward: 0.0539291613793.
# Step: 9640000. Mean Reward: 3.0. Std of Reward: 0.0.
# Step: 9650000. Mean Reward: 3.0. Std of Reward: 0.0.
# Saved Model
# Step: 9660000. Mean Reward: 3.0. Std of Reward: 0.0.
# Step: 9670000. Mean Reward: 3.0. Std of Reward: 0.0.
# Step: 9680000. Mean Reward: 3.0. Std of Reward: 0.0.
# Step: 9690000. Mean Reward: 3.0. Std of Reward: 0.0.
# Step: 9700000. Mean Reward: 3.0. Std of Reward: 0.0.
# Saved Model
# Step: 9710000. Mean Reward: 2.99668246445. Std of Reward: 0.107705006223.
# Step: 9720000. Mean Reward: 3.0. Std of Reward: 0.0.
# Step: 9730000. Mean Reward: 2.99594465649. Std of Reward: 0.0819913465346.
# Step: 9740000. Mean Reward: 3.0. Std of Reward: 0.0.
# Step: 9750000. Mean Reward: 3.0. Std of Reward: 0.0.
# Saved Model
# Step: 9760000. Mean Reward: 3.0. Std of Reward: 0.0.
# Step: 9770000. Mean Reward: 3.0. Std of Reward: 0.0.
# Step: 9780000. Mean Reward: 3.0. Std of Reward: 0.0.
# Step: 9790000. Mean Reward: 3.0. Std of Reward: 0.0.
# Step: 9800000. Mean Reward: 2.99548049477. Std of Reward: 0.105919167204.
# Saved Model
# Step: 9810000. Mean Reward: 3.0. Std of Reward: 0.0.
# Step: 9820000. Mean Reward: 2.99620853081. Std of Reward: 0.123091435683.
# Step: 9830000. Mean Reward: 2.99644549763. Std of Reward: 0.0817415335623.
# Step: 9840000. Mean Reward: 2.99857278782. Std of Reward: 0.0462469602646.
# Step: 9850000. Mean Reward: 3.0. Std of Reward: 0.0.
# Saved Model
# Step: 9860000. Mean Reward: 3.0. Std of Reward: 0.0.
# Step: 9870000. Mean Reward: 3.0. Std of Reward: 0.0.
# Step: 9880000. Mean Reward: 2.99691064639. Std of Reward: 0.100154156847.
# Step: 9890000. Mean Reward: 3.0. Std of Reward: 0.0.
# Step: 9900000. Mean Reward: 2.99952426261. Std of Reward: 0.0154156534215.
# Saved Model
# Step: 9910000. Mean Reward: 2.99407020873. Std of Reward: 0.136106885406.
# Step: 9920000. Mean Reward: 2.99477186312. Std of Reward: 0.124175016189.
# Step: 9930000. Mean Reward: 2.99619771863. Std of Reward: 0.123266654581.
# Step: 9940000. Mean Reward: 3.0. Std of Reward: 0.0.
# Step: 9950000. Mean Reward: 2.99667616334. Std of Reward: 0.107807144522.
# Saved Model
# Step: 9960000. Mean Reward: 2.99857549858. Std of Reward: 0.046203061938.
# Step: 9970000. Mean Reward: 3.0. Std of Reward: 0.0.
# Step: 9980000. Mean Reward: 3.0. Std of Reward: 0.0.
# Step: 9990000. Mean Reward: 2.99644549763. Std of Reward: 0.083178393431.
# Step: 10000000. Mean Reward: 3.0. Std of Reward: 0.0.
# Saved Model
# Saved Model
# INFO:tensorflow:Restoring parameters from ./models/ppo/model-10000001.cptk
# INFO:tensorflow:Restoring parameters from ./models/ppo/model-10000001.cptk
# INFO:tensorflow:Froze 7 variables.
# INFO:tensorflow:Froze 7 variables.
# Converted 7 variables to const ops.

# %% [markdown]
# ### Export the trained Tensorflow graph
# Once the model has been trained and saved, we can export it as a .bytes file which Unity can embed.

# %%
export_graph(model_path, env_name)
# Out:
# INFO:tensorflow:Restoring parameters from ./models/ppo/model-10000001.cptk
# INFO:tensorflow:Restoring parameters from ./models/ppo/model-10000001.cptk
# INFO:tensorflow:Froze 7 variables.
# INFO:tensorflow:Froze 7 variables.
# Converted 7 variables to const ops.
